# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Basic Graph

# %%
x = [0, 1, 2, 3, 4]
y = [0, 2, 4, 6, 8]

# Resize your graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)

plt.figure(figsize=(6, 4), dpi=100)

# plt.plot(x, y, label = '2x', color = 'red', linestyle='--' ,linewidth = 2, marker = '.', markersize = 10, markeredgecolor = 'blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x, y, 'b^--',label = '2x')

# Line 2
# select interval we want to plot points at
x2 = np.arange(0, 4.5, 0.5)
# plt.plot(x2, x2**2, 'r', label = 'x^2')

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label = 'x^2')

# Plot part of the graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Our First Graph', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0, 1, 2, 3, 4])
plt.yticks([0, 2, 4, 6, 8, 10])

# Add a legend
plt.legend()

# Save the graph
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %% [markdown]
# Bar Chart

# %%
labels = ['A', 'B', 'C']
values = [1, 4, 2]

bars = plt.bar(labels, values)

patterns = ['/','O','*']

for bar in bars:
    bar.set_hatch(patterns.pop(0))

# bars[0].set_hatch('/')
# bars[1].set_hatch('O')
# bars[2].set_hatch('*')

plt.figure(figsize=(6, 4), dpi=100)

plt.show()

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8, 5), dpi=300)

plt.title('Gas prices over time (in USD)', fontdict={'fontweight': 'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA,  'b.-', label = 'USA',)
plt.plot(gas.Year, gas.Canada, 'g.-', label = 'Canada')
plt.plot(gas['Year'], gas['South Korea'], 'r.-', label = 'South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label = 'Australia')

# Another way to plot many values!
# coutries_to_look_at = ['USA', 'Canada', 'South Korea', 'Australia']
# for country in gas:
#     # if country != 'Year':
#     if country in coutries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)

plt.xticks(gas.Year[::3].to_list() + [2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %% [markdown]
# Load Fifa Data

# %%
fifa = pd.read_csv('fifa_data.csv')

bins = np.arange(40,110,10)
plt.hist(fifa.Overall, bins = bins)
plt.xticks(bins)
plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.show()

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.pie([left, right], labels = ['Left', 'Right'], autopct='%.2f %%')
plt.title('Foot Preference of FIFA Players')
plt.show()
# Out:
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3388415150.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3388415150.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]
# print(f"{fifa.Weight[1]:.2f}")
plt.style.use('ggplot')
light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa.loc[fifa.Weight >= 200].count()[0]

weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ['Under 125', '125-150', '150-175', '175-200', 'Over 200']
explode = (.4, .2, 0, 0, .4)

plt.pie(weights, labels = labels, autopct='%.2f %%', pctdistance=0.8, explode = explode)

plt.title('Weight Distribution of FIFA Players (in lbs)')
plt.show()
# Out:
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3404196507.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa.loc[fifa.Weight < 125].count()[0]
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3404196507.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3404196507.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3404196507.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
# C:\Users\Arnob\AppData\Local\Temp\ipykernel_16564\3404196507.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   heavy = fifa.loc[fifa.Weight >= 200].count()[0]

# %%
plt.style.use('default')

plt.figure(figsize=(5, 8))

liverpool = fifa.loc[fifa.Club == 'Liverpool']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
man_utd = fifa.loc[fifa.Club == 'Manchester United']['Overall']

labels = ['Liverpool', 'Real Madrid', 'Manchester United']
boxes = plt.boxplot([liverpool, madrid, man_utd], label=labels, patch_artist=True, medianprops={'linewidth': 2})

for box in boxes['boxes']:
    box.set(color='#4286f4', linewidth=2)
    # change fill color
    box.set(facecolor = '#e0e0e0')

plt.title('Professional Football Team Comparison')
plt.ylabel('FIFA Overall Rating')

plt.show()
